# %%
# %pip install google-api-python-client pandas
# Out:
# Requirement already satisfied: google-api-python-client in c:\users\jayax\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (2.198.0)
# Requirement already satisfied: pandas in c:\users\jayax\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (3.0.3)
# Requirement already satisfied: httplib2<1.0.0,>=0.19.0 in c:\users\jayax\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from google-api-python-client) (0.32.0)
# Requirement already satisfied: google-auth!=2.24.0,!=2.25.0,<3.0.0,>=1.32.0 in c:\users\jayax\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from google-api-python-client) (2.56.2)
# Requirement already satisfied: google-auth-httplib2<1.0.0,>=0.2.0 in c:\users\jayax\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from google-api-python-client) (0.4.0)
# Requirement already satisfied: google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0,>=1.31.5 in c:\users\jayax\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from google-api-python-client) (2.33.0)
# Requirement already satisfied: uritemplate<5,>=3.0.1 in c:\users\jayax\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from google-api-python-client) (4.2.0)
# Requirement already satisfied: numpy>=1.26.0 in c:\users\jayax\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from pandas) (2.4.6)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\jayax\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: tzdata in c:\users\jayax\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from pandas) (2026.2)
# Requirement already satisfied: googleapis-common-protos<2.0.0,>=1.63.2 in c:\users\jayax\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0,>=1.31.5->google-api-python-client) (1.75.0)
# Requirement already satisfied: protobuf<8.0.0,>=5.29.6 in c:\users\jayax\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0,>=1.31.5->google-api-python-client) (7.35.1)
# Requirement already satisfied: proto-plus<2.0.0,>=1.24.0 in c:\users\jayax\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0,>=1.31.5->google-api-python-client) (1.28.2)
# Requirement already satisfied: requests<3.0.0,>=2.33.0 in c:\users\jayax\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0,>=1.31.5->google-api-python-client) (2.34.2)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in c:\users\jayax\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from google-auth!=2.24.0,!=2.25.0,<3.0.0,>=1.32.0->google-api-python-client) (0.4.2)
# Requirement already satisfied: cryptography>=38.0.3 in c:\users\jayax\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from google-auth!=2.24.0,!=2.25.0,<3.0.0,>=1.32.0->google-api-python-client) (49.0.0)
# Requirement already satisfied: pyparsing<4,>=3.1 in c:\users\jayax\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from httplib2<1.0.0,>=0.19.0->google-api-python-client) (3.3.2)
# Requirement already satisfied: six>=1.5 in c:\users\jayax\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)
# Requirement already satisfied: cffi>=2.0.0 in c:\users\jayax\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from cryptography>=38.0.3->google-auth!=2.24.0,!=2.25.0,<3.0.0,>=1.32.0->google-api-python-client) (2.1.0)
# Requirement already satisfied: pyasn1<0.7.0,>=0.6.1 in c:\users\jayax\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from pyasn1-modules>=0.2.1->google-auth!=2.24.0,!=2.25.0,<3.0.0,>=1.32.0->google-api-python-client) (0.6.4)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\users\jayax\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from requests<3.0.0,>=2.33.0->google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0,>=1.31.5->google-api-python-client) (3.4.9)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\jayax\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from requests<3.0.0,>=2.33.0->google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0,>=1.31.5->google-api-python-client) (3.18)
# Requirement already satisfied: urllib3<3,>=1.26 in c:\users\jayax\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from requests<3.0.0,>=2.33.0->google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0,>=1.31.5->google-api-python-client) (2.7.0)
# Requirement already satisfied: certifi>=2023.5.7 in c:\users\jayax\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from requests<3.0.0,>=2.33.0->google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0,>=1.31.5->google-api-python-client) (2026.7.22)
# Requirement already satisfied: pycparser in c:\users\jayax\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from cffi>=2.0.0->cryptography>=38.0.3->google-auth!=2.24.0,!=2.25.0,<3.0.0,>=1.32.0->google-api-python-client) (3.0)
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 24.0 -> 26.2
# [notice] To update, run: C:\Users\jayax\AppData\Local\Microsoft\WindowsApps\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\python.exe -m pip install --upgrade pip

# %%
import pandas as pd
from googleapiclient.discovery import build

# %%
API_KEY = "AIzaSyBRBQPtg-LNIYmuwKDSwO_9vW4as2Z-Aj4"

youtube = build(
    "youtube",
    "v3",
    developerKey=API_KEY
)

# %%
countries = [
    "US", "IN", "GB", "CA", "AU",
    "JP", "KR", "DE", "FR", "BR",
    "MX", "IT", "ES", "NL", "SE"
]

all_videos = []

# %%
for country in countries:

    request = youtube.videos().list(
        part="snippet,statistics,contentDetails",
        chart="mostPopular",
        regionCode=country,
        maxResults=50
    )

    response = request.execute()

    for item in response["items"]:

        all_videos.append({

            "Country": country,
            "Video ID": item["id"],
            "Title": item["snippet"]["title"],
            "Channel": item["snippet"]["channelTitle"],
            "Published": item["snippet"]["publishedAt"],
            "Category ID": item["snippet"]["categoryId"],
            "Views": item["statistics"].get("viewCount"),
            "Likes": item["statistics"].get("likeCount"),
            "Comments": item["statistics"].get("commentCount"),
            "Duration": item["contentDetails"]["duration"] })

# %%
df = pd.DataFrame(all_videos)

# %%
# Add Today's Date as new column
df['Date_of_Record'] = pd.Timestamp.now().strftime('%Y-%m-%d')
